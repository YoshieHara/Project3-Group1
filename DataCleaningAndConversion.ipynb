# %%
# Import dependencies
import pandas as pd
pd.set_option('max_colwidth', 1400)

# %%
# Read the data into a Pandas DataFrame (crimes.xlsx)
all_crimes_data_df = pd.read_excel('crimes.xlsx')
all_crimes_data_df.head()
# Out:
#    Year Year ending             Offence Division  \
# 0  2023       March  A Crimes against the person
# 1  2023       March  A Crimes against the person
# 2  2023       March  A Crimes against the person
# 3  2023       March  A Crimes against the person
# 4  2023       March  A Crimes against the person
#
#                  Offence Subdivision  \
# 0  A10 Homicide and related offences
# 1  A10 Homicide and related offences
# 2  A10 Homicide and related offences
# 3  A10 Homicide and related offences
# 4   A20 Assault and related offences
#
#                                           Offence Subgroup  Offence Count  \
# 0                                               A11 Murder             57
# 1                                     A12 Attempted murder             24
# 2  A14 Manslaughter & A13  Accessory/ conspiracy to murder             22
# 3                                A15 Driving causing death             96
# ...

# %%
# Get a brief summary of the all_crimes_data_df DataFrame to check data types and number of entries.
brief_summry = all_crimes_data_df.info()
brief_summry
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1123 entries, 0 to 1122
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         1123 non-null   int64
#  1   Year ending                  1123 non-null   object
#  2   Offence Division             1123 non-null   object
#  3   Offence Subdivision          1123 non-null   object
#  4   Offence Subgroup             1123 non-null   object
#  5   Offence Count                1123 non-null   int64
#  6   Rate per 100,000 population  1123 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 61.5+ KB

# %%
# Remove any empty rows (all_crimes_data_df)
all_crimes_data_df.dropna()
# Out:
#       Year Year ending             Offence Division  \
# 0     2023       March  A Crimes against the person
# 1     2023       March  A Crimes against the person
# 2     2023       March  A Crimes against the person
# 3     2023       March  A Crimes against the person
# 4     2023       March  A Crimes against the person
# ...    ...         ...                          ...
# 1118  2014       March             F Other offences
# 1119  2014       March             F Other offences
# 1120  2014       March             F Other offences
# 1121  2014       March             F Other offences
# 1122  2014       March             F Other offences
#
#                     Offence Subdivision  \
# 0     A10 Homicide and related offences
# 1     A10 Homicide and related offences
# 2     A10 Homicide and related offences
# 3     A10 Homicide and related offences
# 4      A20 Assault and related offences
# ...                                 ...
# 1118         F90 Miscellaneous offences
# ...

# %%
# Read the data into a Pandas DataFrame (Drugs.xlsx)
drugs_df = pd.read_excel('Drugs.xlsx')
drugs_df.head()
# Out:
#    Year Year ending               Offence Subdivision     Offence Group  \
# 0  2023       March  C10 Drug dealing and trafficking  C11 Drug dealing
# 1  2023       March  C10 Drug dealing and trafficking  C11 Drug dealing
# 2  2023       March  C10 Drug dealing and trafficking  C11 Drug dealing
# 3  2023       March  C10 Drug dealing and trafficking  C11 Drug dealing
# 4  2023       March  C10 Drug dealing and trafficking  C11 Drug dealing
#
#                         Offence Description CSA Drug Type  Offence Count
# 0         INTRODUCE DRUG INTO REMAND CENTRE  Not Recorded              4
# 1  SEND NARCOTIC SUBSTANCE IN POST-C'WEALTH  Not Recorded              3
# 2       SUPPLY A CONTROLLED DRUG TO A CHILD  Not Recorded             11
# 3   SUPPLY DOD TO CHILD - USE BY THAT CHILD  Not Recorded             33
# 4  SUPPLY DOD TO CHILD-TO SUPPLY ANOR PERSN  Not Recorded              2

# %%
# Get a brief summary of the drugs_df DataFrame to check data types and number of entries.
brief_summry = drugs_df.info()
brief_summry
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 2073 non-null   int64
#  1   Year ending          2073 non-null   object
#  2   Offence Subdivision  2073 non-null   object
#  3   Offence Group        2073 non-null   object
#  4   Offence Description  2073 non-null   object
#  5   CSA Drug Type        2073 non-null   object
#  6   Offence Count        2073 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 113.5+ KB

# %%
# Remove any empty rows (drugs_df)
drugs_df.dropna()
# Out:
#       Year Year ending               Offence Subdivision  \
# 0     2023       March  C10 Drug dealing and trafficking
# 1     2023       March  C10 Drug dealing and trafficking
# 2     2023       March  C10 Drug dealing and trafficking
# 3     2023       March  C10 Drug dealing and trafficking
# 4     2023       March  C10 Drug dealing and trafficking
# ...    ...         ...                               ...
# 2068  2014       March           C90 Other drug offences
# 2069  2014       March           C90 Other drug offences
# 2070  2014       March           C90 Other drug offences
# 2071  2014       March           C90 Other drug offences
# 2072  2014       March           C90 Other drug offences
#
#                 Offence Group                       Offence Description  \
# 0            C11 Drug dealing         INTRODUCE DRUG INTO REMAND CENTRE
# 1            C11 Drug dealing  SEND NARCOTIC SUBSTANCE IN POST-C'WEALTH
# ...

# %%
# Export both dataframes as CSV files.
all_crimes_data_df.to_csv("crimes.csv", index=False)

drugs_df.to_csv("drugs.csv", index=False)
